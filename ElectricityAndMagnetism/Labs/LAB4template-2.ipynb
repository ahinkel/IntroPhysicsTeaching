# %% [markdown]
# Lab 4 - RC circuits
#
# You can press control+Enter (windows) or Command+Enter (mac) to run a block of code.
#
# Fill in all variables or equations where you see a [FILL IN ...]
#
# The lab packet has some additional coding tools that you may need.

# %%
# These are packages that provide useful tools for math and plotting.
import numpy as np
from matplotlib import pyplot as plt

# Note that any thing after a '#' is a comment. It is not executable code. 

# We can define variabels in the manner below.  
R =   # Resistance in Ohms [FILL IN number]
C = 1.00 # Capacitance in Farads
Vbatt =   # Voltage of Battery (or Direct Current power supply) in Volts [FILL IN number]


# We can make calculations by simply refering to the variables we defined earlier.
tau = R*C # Time Constant in seconds

# Your data goes here, in a list of numbers called an array, with values separated by commas.
t = np.array([0, 15, 30,])  # Times (in seconds) at which measurements were made. [FILL IN values]
VR = np.array([3.00, ])        # Potential difference across the RESISTOR (in Volts) [FILL IN values]
VC = Vbatt - VR                    # Potential difference across the CAPACITOR (in Volts) [FILL IN equation] 

# This is how we plot the data.
# The first variable is on the horizontal axis, the second on the vertical.
plt.plot(t, VC, 'k.') #Note 'k.' means plot black dots.  You can choose other options.
plt.title("RC Circuit Lab 4 - Charging Capacitor")
plt.xlabel("Time (seconds)")
plt.ylabel("Voltage across Capacitor (Volts)")
plt.show()

# Try creating another code snippet to calculate and plot the data in such a way that it is linear.
# Please be sure to define new variable(s).
# We are doing this because fitting a line is much easier than more complex functions.
# This will also let us measure the time constant. (Think about why!)
Y =  #[FILL IN equation]

plt.plot(t, Y, 'r.')
plt.title("RC Circuit Lab 4 - Charging Capacitor - Linear Version")
plt.xlabel("Time (seconds)")
plt.ylabel("Y (units)") # [FILL IN units]
plt.show()

# %% [markdown]
# We can also fit a line to the data:

# %%
# import packages:
import numpy as np                   # Numpy is great for crunching numbers
from matplotlib import pyplot as plt # Matplotlib is for making plots
from scipy.optimize import curve_fit # Curve_fit is for best fit line calculations

# Note that in this code panel, the variables you defined above will still work.

# This is how we define a function.
# A function is any piece of code that takes input (called arguments)
# and spits out (returns) an object (perhaps a number)
def lineEquation(x, m, b):
    return (m * x) + b

# To "call" a function (in other words: use it), simply type the function's name 
# and "pass" (input) the necessary arguments (input)
# for example, if we'd like to calculate y=3x+2 for x=5:
lineEquation(5, 3, 2) 

# Hopefully your code printed the number 17 to your screen below (3*5 + 2 = 17)

# %% [markdown]
# The above code just defined and tested the function.
#
# The code to do the actual fit is below:

# %%
# In order to fit data to a function (like lineEquation), we must do the following:
# popt, pcov = curve_fit(name of function to fit to data, x-axis data, y-axis data)
# popt and pcov are new variables that "catch" the output of the curve_fit function.
popt, pcov = curve_fit(lineEquation, t, Y)
# The code below prints the curve fit parameters (arguments) in the order 
# of appearance in the definition of the function (except the first argument
# which is the independent variable). In this case it will print m, b.
popt 

# You can access each 'element' in the array named 'popt' by typing 
#popt[0] #(first element)
#popt[1] #(second element)
#Remove the first '#' in each line if you want to see the 0th and 1st element of popt individually

# %% [markdown]
# Now we can plot both the data and the best fit line.

# %%
# Code continues between cells, just be sure to run the earlier code.
# That is, variables you defined in code cells above can still be used in code cells below

# You can plot your data and the best fit line by filling in the code below:
plt.plot(t, Y, 'k.') # If you correctly derived an expression with a linear relationship to time, this should plot linear data 
plt.plot(t, lineEquation(t, *popt),'r-') # This line  of code plots your best fit line
plt.title("RC Circuit Lab 4 - Charging Capacitor Linear Version")
plt.xlabel("Time (seconds)")
plt.ylabel("Y (units)") # [FILL IN units]
plt.show()

# Does your line appear to be a good fit?  Why or why not?
# Interpret the slope of the line in terms of the math you did ealier.  What does it tell you?
# Interpret the y-intercept of the line.  What does it tell you?

# %% [markdown]
# Can you reproduce this process for your discharging capacitor data?
#
# Feel free to copy and paste relevant portions of your code, just be sure to update the calculations as needed.

# %%
#Your new code here (wait for the next code cell to plot your data/fit):

# import packages:
import numpy as np                   # Numpy is great for crunching numbers
from matplotlib import pyplot as plt # Matplotlib is for making plots
from scipy.optimize import curve_fit # Curve_fit is for best fit line calculations

# The code below needs to be included in your lab packet for #9.

# [FILL IN code]

# %% [markdown]
# Please fill out the plotting code below in order to plot your transformed discharging capacitor data as a line:

# %%
# Plotting code:

# [FILL IN code]
